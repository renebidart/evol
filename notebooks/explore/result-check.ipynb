# %% [markdown]
# # Check

# %%
import os
import sys
import glob
import random
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data
import torchvision.models as models
from torchvision import datasets, models, transforms
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

fast_ai_dir = '/media/rene/Data/fastai/'
sys.path.append(fast_ai_dir)

SEED = 101
np.random.seed(SEED)
from torchvision import datasets, models, transforms

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Add the src directory for functions
src_dir = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), 'src')
print(src_dir)
sys.path.append(src_dir)

# import my functions:

torch.cuda.set_device(1)
print(torch.cuda.is_available())
print(torch.cuda.current_device())
# Out:
# /media/rene/Data/learn-lr/src
# True
# 1

# %% [markdown]
# ## Look at old tests
# * Loop through the

# %%
mnist_10 = pickle.load( open( "/media/rene/Data/data/learn-lr/output/evol_mnist_gener_50_numsch_10_epochs_10", "rb" ) )

# %%
print(len(mnist_10))
print(mnist_10[0])
# Out:
# 50
# (98.18333333333334, [0.03621526576418882, 0.27040649184728455, 1.547088084671871e-05, 0.13277769410910947, 0.12000482555611325, 1.5671720724177722e-05, 0.00012778515685704775, 0.003339204473524803, 0.0662942169551747, 0.0008284995607136705])

# %%
nrow = 5
ncol = 1
fig, axs = plt.subplots(nrow, ncol, figsize=(15,25))
for i, ax in enumerate(fig.axes):
    ax.plot(list(range(10)), mnist_10[int(i*10)][1])
    plt.title('Generation: '+ str(i) + ' Acc: '+ str(mnist_10[int(i*10)][0]))
    ax.set_title('Generation: '+ str(i) + ' Acc: '+ str(data[int(i*5)][0]))
    ax.set_ylabel('LR')

# %%
## MNIST with 5 epochs

# %%
mnist_5 = pickle.load( open( "/media/rene/Data/data/learn-lr/output/evol_mnist_gener_50_numsch_5_epochs_5", "rb" ) )

# %%
nrow = 5
ncol = 1
fig, axs = plt.subplots(nrow, ncol, figsize=(15,25))
for i, ax in enumerate(fig.axes):
    ax.plot(list(range(5)), mnist_5[int(i*10)][1])
    ax.set_title('Generation: '+ str(i) + ' Acc: '+ str(data[int(i*5)][0]))
    ax.set_ylabel('LR')

# %% [markdown]
# ## R2

# %%
data = pickle.load( open( '/media/rene/Data/data/learn-lr/output_r2/evol_mnist_gener_50_numsch_10_epochs_10', "rb" ) )

nrow = 5
ncol = 1
fig, axs = plt.subplots(nrow, ncol, figsize=(15,25))
for i, ax in enumerate(fig.axes):
    ax.plot(list(range(10)), data[int(i*10)][1])
    ax.set_title('Generation: '+ str(i) + ' Acc: '+ str(data[int(i*10)][0]))
    ax.set_ylabel('Learnign rate')

# %%
data = pickle.load( open( '/media/rene/Data/data/learn-lr/output_r2/evol_mnist_gener_50_numsch_5_epochs_5', "rb" ) )

nrow = 5
ncol = 1
fig, axs = plt.subplots(nrow, ncol, figsize=(15,25))
for i, ax in enumerate(fig.axes):
    ax.plot(list(range(5)), data[int(i*10)][1])
    ax.set_title('Generation: '+ str(i) + ' Acc: '+ str(data[int(i*5)][0]))
    ax.set_ylabel('LR')
